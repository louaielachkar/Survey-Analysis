# %%
import pandas as pd
from nltk.tokenize import word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords

import gensim, spacy, logging, warnings
import gensim.corpora as corpora
from gensim.utils import  simple_preprocess
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt

# %% [markdown]
# ### Preparation

# %%
df = pd.read_excel("enquete_clean.xlsx")
df = df.fillna('-')
df
# Out:
#       ID  \
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
# ..   ...
# 98    99
# 99   100
# 100  101
# 101  102
# 102  103
#
#                                        Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous  \
# 0                                                                                                      -
# 1                                                                                                      -
# 2                                                                                                      -
# 3    administratives : gestion des documents, title-block, flux d'approbation, préparation de work pa...
# 4                                                                                                      -
# ..                                                                                                   ...
# 98                                                            Interface Management between the entities
# 99                                                                                                     -
# 100                                                                                                    -
# 101                                                                                                    -
# 102                                                                                                    -
#
#                                                                   Quelles sont vos aspirations futures ?  \
# 0                                             Une croissance sur des projets techniques plus complexes.
# 1                                                               continuer à gérer des équipes de projets
# 2    j'ai répondu au questionnaire comme si j étais toujours PM dans un secteur, fonction que j ai qu...
# 3              Avoir une équipe à gérer de chargés d'affaires. Le duo PM/TPM ne s'applique pas forcément
# 4                                                                                 Rester Project manager
# ..                                                                                                   ...
# 98                         Progressively lead the Company, Buniness line within span of next 3-5 years\n
# 99                                                             Team management, with technical aspects.
# 100                                                          To be better Communicator, adaptable ,agile
# 101  To lead  team on group  level for international  project  where multiple  entities will be invol...
# 102                                                                               Top management and CEO
#
#                Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?  \
# 0                                                                                                      -
# 1     arrêter cette ambiguïté du tandem PM et TPM, il faut un seul patron dans une équipe et c'est le PM
# 2    Difficulté d'avoir accès à des ressources de qualité (mobilisée sur un autre projet ou pas dispo...
# 3                                                                               reconnaissance salariale
# 4                                                                                                      -
# ..                                                                                                   ...
# 98                                                     Better Project Management organisation (Staffing)
# 99                                                                                                     -
# 100                                                                                                    -
# 101                                                                                                    -
# 102                                                                                                    -
#
#     A quel niveau le placeriez-vous dans le ranking ci-dessus ? (1 = le PLUS important - 10 = le MOINS important)  \
# 0                                                                                                      -
# 1                                                                                                      5
# 2                                                                                                      1
# 3                                                                                                      3
# 4                                                                                                      -
# ..                                                                                                   ...
# 98                                                                                                     3
# 99                                                                                                     -
# 100                                                                                                    4
# 101                                                                                                    1
# 102                                                                                                    -
#
#                                                                    Si oui ou non, expliquez pourquoi ...  \
# 0    J’ai l’impression que l’entreprise accorde beaucoup d’importance aux certifications détenues par...
# 1                                                                                   ce serait une redite
# 2                               Ancrage des formations suivies en interne\nValorisation de notre métier
# 3                                                                                          déjà certifié
# 4                                                  Pas le temps personnel a accorder au vu de la famille
# ..                                                                                                   ...
# 98   Yes surely.\nHowever time and the heavy workload has been the constraint for taking out time for...
# 99                        It's always interesting to have training / certification to improve our skills
# 100                                                                                   I am PMP Certified
# 101   PMP certification  will help us to apply worlds best proven Project Management  practices which...
# 102                                                                               I am already certified
#
#                                                                              Si autre, à préciser ... :1  \
# 0                                                                                                      -
# 1                                                                                                      -
# 2                                                                                                      -
# 3                                                                                                      -
# 4                                                                                                      -
# ..                                                                                                   ...
# 98   Clear roles and responsibility in case of shared responsibilities.\nBetter support in terms of t...
# 99                                                                                                     -
# 100                                                                                                    -
# 101                                                                                                    -
# 102                                                                                                    -
#
#     Si autre, à préciser ... :2 Si autre, à préciser ... :3  \
# 0                             -                           -
# 1                             -                           -
# 2                             -                           -
# 3                             -                           -
# 4                             -                           -
# ..                          ...                         ...
# 98                            -                           -
# 99                            -                           -
# 100                           -                           -
# 101                           -                           -
# 102                           -                           -
#
#                                                                              Si autre, à préciser ... :4  \
# 0                                                                                                      -
# 1                                                                                                      -
# 2                                                                                                      -
# 3                                                                                                      -
# 4                                                                                                      -
# ..                                                                                                   ...
# 98   Engineering and technology - Emphasize focus on technological enhancements for the offered solut...
# 99                                                                                                     -
# 100                                                                                                    -
# 101                                                                                                    -
# 102                                                                                                    -
#
#     Si autre, à préciser ... :5 Si autre, à préciser ... :6  \
# 0                             -                           -
# 1                             -                           -
# 2                             -                           -
# 3                             -                           -
# 4                             -                           -
# ..                          ...                         ...
# 98                            -                           -
# 99                            -                           -
# 100                           -                           -
# 101                           -                           -
# 102                           -                           -
#
#         Si autre, à préciser ... :7 Si autre, à préciser ... :8  \
# 0                                 -                           -
# 1                                 -                           -
# 2                                 -                           -
# 3                                 -                           -
# 4                                 -                           -
# ..                              ...                         ...
# 98   Project Monitoring and Control                           -
# 99                                -                           -
# 100                               -                           -
# 101                               -                           -
# 102                               -                           -
#
#                                        Commentaire libre pour vous exprimer sur votre niveau de stress :  \
# 0                                                                                                      -
# 1                                                                                                      -
# 2                                                                                                      -
# 3                                                                                                      -
# 4                                                                                                      -
# ..                                                                                                   ...
# 98   Lack of Consistancy in terms of support (Support offered based on results -Corrective and not pr...
# 99                                                                                                     -
# 100                                                                                                    -
# 101  Improper Work load management  of individual & not giving appropriate  guidance  & support from ...
# 102  Senior managers who are suppose to make and give critical decision, seems to be on back-foot. Fi...
#
#                         Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?  \
# 0    La culture du groupe \nLa structuration et l’harmonisation des processus \nLa disponibilité des ...
# 1                                         diversité des business, excepté la défense.\nla localisation\n
# 2                                    Variété des projets, niveau de responsabilité assez jeune, produits
# 3    environnement international\nnouveaux produits (hydrogène, tours solaire, etc)\ngroupe en expans...
# 4                                                          Groupe à taille humaine\nAutonomie\nDiversité
# ..                                                                                                   ...
# 98                                                                    Flexibility \nTrust \nOpportunity
# 99   Freedom given to the project manager\nNew techical skills discoverd\nRelation ship with other JC...
# 100  1. The way John Cockerill's presence in different continents supports in project execution.\n2. ...
# 101  1.Tools  like PROMOCORE, SAP & MSP help a lot in monitoring  & controlling  scope, schedule & co...
# 102                                                                       Good initiative in using O365.
#
#                             Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?  \
# 0    L’absence de vision à long terme \nLe manque de communication du management \nL’absence de leade...
# 1    entreprise qui donne une image moderne mais qui est ancrée dans son passé, gérée par des manager...
# 2    combat permanent pour les ressources, portefeuille de produits assez large- pour un non technici...
# 3    la charge administrative et trop d'outils différents mis en place\nla perte de référents techniq...
# 4                              Lourdeur administrative\nManque de support informatique\nTrop de réunions
# ..                                                                                                   ...
# 98                                           Inconsistancy\nDecision making\nLoosing Technical expertise
# 99   Complexity of promocore\nDificulty to have a clear process for PM\nLack of support for secretari...
# 100  1. Strong Functional matrix, in spite of being an OEM\n2. Lack of live platform for Project Moni...
# 101  1. Technical information sharing within different  entities are improper \n2. Cost & margin shar...
# 102  Senior or Top management do not own the responsibility of negative outcome of their decisions an...
#
#                           Selon vous, quelle est la première action à prendre pour valoriser le métier ?  \
# 0    Donner davantage d’autonomie et de pouvoir au chef de projet sur son projet. \nIl n’est pas norm...
# 1    remettre le PM au centre du projet, c'est le patron de l'équipe projet.\nmoderniser cet outil pr...
# 2             réduire la charge horaire \ntrouver des moyens d'optimiser les taches très administratives
# 3    perspective d'avenir :  A-t-on vraiment envie d'être PM sur des HRSGs pendant 10 ans?\nRendre pl...
# 4                                                                           Reconnaissance hiéerarchique
# ..                                                                                                   ...
# 98   Aggressive in the market and Pragmatism in execution (Right Prioritisation)...and focus on custo...
# 99                                         Recognize at is just value the work and give future prospects
# 100                    1. Professional Ethics\n2. Proper and proactive planning\n3. Vision of objectives
# 101                                                       good training  & global exposure  to the team
# 102  Each functional team need to own the project, it's not just Project Manager.\nProject Manager sa...
#
#     Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pris le temps de répondre à cette enquête  \
# 0                                                                                                      -
# 1                                                                                           bonne chance
# 2                                                                                                      -
# 3                                                                                                      -
# 4                                                                                                      -
# ..                                                                                                   ...
# 98   Change is Inevitable, but constantantly changing maybe harmful.  Good if it is predictable.\n\nT...
# 99                                                                                                     -
# 100           Thank you for giving this opportunity to express, hoping every comment brings some value.
# 101  1. Improvement in investment  for different  sectors  in India other  than steel.\n2. Wedges  fo...
# 102                                                                                                    -
#
#     lang
# 0     fr
# 1     fr
# 2     fr
# 3     fr
# 4     fr
# ..   ...
# 98    en
# 99    en
# 100   en
# 101   en
# 102   en
#
# [103 rows x 20 columns]

# %%
cols = df.columns.tolist()
cols
# Out:
# ['ID',
#  "Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous",
#  'Quelles sont vos aspirations futures ?',
#  'Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?',
#  'A quel niveau le placeriez-vous dans le ranking ci-dessus ? (1 = le PLUS important - 10 = le MOINS important)',
#  'Si oui ou non, expliquez pourquoi ...',
#  'Si autre, à préciser ... :1',
#  'Si autre, à préciser ... :2',
#  'Si autre, à préciser ... :3',
#  'Si autre, à préciser ... :4',
#  'Si autre, à préciser ... :5',
#  'Si autre, à préciser ... :6',
#  'Si autre, à préciser ... :7',
#  'Si autre, à préciser ... :8',
#  'Commentaire libre pour vous exprimer sur votre niveau de stress :',
#  'Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?',
#  'Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?',
#  'Selon vous, quelle est la première action à prendre pour valoriser le métier ?',
#  "Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pris le temps de répondre à cette enquête",
#  'lang']

# %%
# Combining comments
df['Si autre, à préciser(combined)'] = df['Si autre, à préciser ... :1'] + df['Si autre, à préciser ... :2'] + df['Si autre, à préciser ... :3'] + df['Si autre, à préciser ... :4'] + df['Si autre, à préciser ... :5'] + df['Si autre, à préciser ... :6'] + df['Si autre, à préciser ... :7'] + df['Si autre, à préciser ... :8']

# %%
cols.append('Si autre, à préciser(combined)')

# %%
to_remove = ['ID',
            'lang',
            'A quel niveau le placeriez-vous dans le ranking ci-dessus ? (1 = le PLUS important - 10 = le MOINS important)',
             'Si autre, à préciser ... :1',
             'Si autre, à préciser ... :2',
             'Si autre, à préciser ... :3',
             'Si autre, à préciser ... :4',
             'Si autre, à préciser ... :5',
             'Si autre, à préciser ... :6',
             'Si autre, à préciser ... :7',
             'Si autre, à préciser ... :8',     
           ]
for col in to_remove:
    cols.remove(col)

# %%
df[cols].columns.tolist()
# Out:
# ["Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous",
#  'Quelles sont vos aspirations futures ?',
#  'Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?',
#  'Si oui ou non, expliquez pourquoi ...',
#  'Commentaire libre pour vous exprimer sur votre niveau de stress :',
#  'Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?',
#  'Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?',
#  'Selon vous, quelle est la première action à prendre pour valoriser le métier ?',
#  "Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pris le temps de répondre à cette enquête",
#  'Si autre, à préciser(combined)']

# %%
combined = df[cols].transpose()

# %%
combined
# Out:
#                                                                                                                                                                                                       0    \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                                                         Une croissance sur des projets techniques plus complexes.
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                 J’ai l’impression que l’entreprise accorde beaucoup d’importance aux certifications détenues par...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                      La culture du groupe \nLa structuration et l’harmonisation des processus \nLa disponibilité des ...
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          L’absence de vision à long terme \nLe manque de communication du management \nL’absence de leade...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        Donner davantage d’autonomie et de pouvoir au chef de projet sur son projet. \nIl n’est pas norm...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                       1    \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                                                                           continuer à gérer des équipes de projets
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?              arrêter cette ambiguïté du tandem PM et TPM, il faut un seul patron dans une équipe et c'est le PM
# Si oui ou non, expliquez pourquoi ...                                                                                                                                                ce serait une redite
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                           diversité des business, excepté la défense.\nla localisation\n
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          entreprise qui donne une image moderne mais qui est ancrée dans son passé, gérée par des manager...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        remettre le PM au centre du projet, c'est le patron de l'équipe projet.\nmoderniser cet outil pr...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                         bonne chance
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                       2    \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                j'ai répondu au questionnaire comme si j étais toujours PM dans un secteur, fonction que j ai qu...
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?             Difficulté d'avoir accès à des ressources de qualité (mobilisée sur un autre projet ou pas dispo...
# Si oui ou non, expliquez pourquoi ...                                                                                            Ancrage des formations suivies en interne\nValorisation de notre métier
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                      Variété des projets, niveau de responsabilité assez jeune, produits
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          combat permanent pour les ressources, portefeuille de produits assez large- pour un non technici...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                 réduire la charge horaire \ntrouver des moyens d'optimiser les taches très administratives
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                       3    \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                     administratives : gestion des documents, title-block, flux d'approbation, préparation de work pa...
# Quelles sont vos aspirations futures ?                                                                          Avoir une équipe à gérer de chargés d'affaires. Le duo PM/TPM ne s'applique pas forcément
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                        reconnaissance salariale
# Si oui ou non, expliquez pourquoi ...                                                                                                                                                       déjà certifié
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                      environnement international\nnouveaux produits (hydrogène, tours solaire, etc)\ngroupe en expans...
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          la charge administrative et trop d'outils différents mis en place\nla perte de référents techniq...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        perspective d'avenir :  A-t-on vraiment envie d'être PM sur des HRSGs pendant 10 ans?\nRendre pl...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                             4    \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                             -
# Quelles sont vos aspirations futures ?                                                                                                                   Rester Project manager
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                     -
# Si oui ou non, expliquez pourquoi ...                                                                                     Pas le temps personnel a accorder au vu de la famille
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                             -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                  Groupe à taille humaine\nAutonomie\nDiversité
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          Lourdeur administrative\nManque de support informatique\nTrop de réunions
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                                                     Reconnaissance hiéerarchique
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                          -
# Si autre, à préciser(combined)                                                                                                                                         --------
#
#                                                                                                                                                                                                       5    \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                        Dessin technique
# Quelles sont vos aspirations futures ?                                                                                                                                                    Responsable R&D
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                            Travailler en équipe
# Si oui ou non, expliquez pourquoi ...                                                                 Pour être sur d'appliquer correctement une bonne gestion de projet à mes affaires pour qu'elles ...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                                          Dimension international, Formation, Opportunité
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                                                                                                                   Pas d'avis
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                                   L'aspect non répétitif, non monotone, découverte de plein de technologie
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                       6    \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                          Knowledge Management\nCoaching
# Quelles sont vos aspirations futures ?                                                                                                       not relevant for this survey
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                                                                     Standardization
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                     Challenging, flexible and motivating
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          PM is not seen as a decision maker fully accountable for his choise
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                                               Create a more accountable PM
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                    -
# Si autre, à préciser(combined)                                                                                                                                   --------
#
#                                                                                                                                                                                                       7    \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                Pouvoir gérer des projets plus gros/complexes où j'ai des personnes vraiment impliqués dessus (e...
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                 Oui car j'ai besoin d'outils pour être à même de gérer des projets de divers types, de plus en p...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     Mieux savoir faire les parts de choses et "remballer" les clients avec ses attentes peu cohérent...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                                        Polyvalence - Vue d'ensemble\nContacts\nConcret\n
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                                                                Administratif\nCollaborateurs non motivés\nTrajets en voiture
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        Remettre le chef de projet au centre du projet et alléger certaines procédures/formulaires inter...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                        - Plus challenger\n- Savoir monter au front lors de situations délicates avec clients/fournisseu...
#
#                                                                                                                                                                                                       8    \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                Tout dépend de comment le métier de gestion de projet évoluéra au fil des années chez JCD. En pr...
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                 Je pense que la certification PMBOK nous donne beaucoup de possibilités. Les outils et méthodes ...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                                           Flexibilité, Autonomie et Support hiérarchique
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                                           Manque d'outil, processus pas adaptés (exercice budgétaire), quantité de reporting
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        Travailler en mode gestion de projet pour du vrai. Adapter / implémenter le mode multiprojet à l...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                       9    \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                                                     Travailler sur des projets dans différentes parties du monde.
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                                            Cela facilite la mobilité car nous travaillons  avec les mêmes standards
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     Il y a un manque de soutien à la fonction de PM et cette fonction est systématiquement pointées ...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                          diversité des projets\nprojets internationaux\nniveaux des challenges proposés
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          Trop des niveaux de management et de fonctions transversales peu rentables \nBeaucoup trop de Fr...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        Clarifier les statuts des freelance ( durée ou objet de la mission ). Il y a trop de freelance q...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                       ...  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                     ...
# Quelles sont vos aspirations futures ?                                                                ...
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?             ...
# Si oui ou non, expliquez pourquoi ...                                                                 ...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     ...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                      ...
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          ...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        ...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...  ...
# Si autre, à préciser(combined)                                                                        ...
#
#                                                                                                                                                                                                       93   \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                VENDOR DISCUSSION;AUDITING SUPPORT INTERNAL AND EXTERNAL
# Quelles sont vos aspirations futures ?                                                                                                             TO WORK IN DIFFERNT ENTITY IN GROUP TO EXPLORE GLOBALY
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                              PROPER COORDINATION BETWEEN ALL ENTITIES IN GROUPE
# Si oui ou non, expliquez pourquoi ...                                                                                                                                    IT IS GOOD FOR ENHANCING SKILLS
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                            workload is very much  for current situation
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                           1) Global exposer 2) Good management 3) Good working condition
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          1)Most of the activities are going worldwide in group in reached to employees \n2)Internal vacan...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                                              Proper coordination with different entities across the globe
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                       94   \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                     Functional activities like Participation in Kaizen, Daily Management, Opportunities be explored ...
# Quelles sont vos aspirations futures ?                                                                - Lead Projects Team at JC (all sectors option open preferred within India)\n- Lead Portfolio of...
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?             - Project Management with exposure to techno commercial experience & Industry experience as END ...
# Si oui ou non, expliquez pourquoi ...                                                                 I have attended the PMP foundation course from PMI already however could not appear on the exam ...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     Stress levels go high as - \n- functional goals supersede Project goals, increases MUDA (Waste) ...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                       - JCIL Project management concepts are bit different than JC as group but interesting to work w...
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                           - Matrix organization as a concept still not being rooted into individuals but functional domin...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        - Grab more orders to sustain in the business \n- Motivate employees to be committed, take chall...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...  Good initiative from the head quarters for a noble cause. Project Managers are key personnel on ...
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                       95   \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                     Babysitting.\nWe have a VERY WEAK mid level management team (department managers) in the energy ...
# Quelles sont vos aspirations futures ?                                                                I would like to stay in project management and improve my skills and grow our team to reach its ...
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?             Schedule. Currently there is no functional schedule for engineering and thus, no way to hold eng...
# Si oui ou non, expliquez pourquoi ...                                                                                                                                            Already a certified PMP.
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     Mid level management (department managers) are non-existent/unresponsive and it makes it difficu...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                                               The POTENTIAL to grow and be successful.\n
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                                               Mid level leadership.\nAccountability at ALL LEVELS.\nStaffing inefficiencies.
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        It is not the value of the profession, it is the environment we have created surrounding the pro...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                             Hope someone actually reads this and its worth anything.
# Si autre, à préciser(combined)                                                                        We have a general lack of Project Management experience. There is no mentorship program in place...
#
#                                                                                                                                                                                                       96   \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                training
# Quelles sont vos aspirations futures ?                                                                I would like to stick with John Cockerill and work in project management a little longer but I w...
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?              better support from mid/executive management, quicker responses on items concerning urgent issues,
# Si oui ou non, expliquez pourquoi ...                                                                                                                                                       I have my PMP
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     I would say my stress level is a 3 just in comparison to where it has been over the past year bu...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                           - working with people around the globe\n- diverse technologies
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          - reporting and constant changing in reporting \n- inefficient tools & processes (sometimes a co...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                                                                    fix the processes, procedures and tools
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                       97   \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                 purchasing, site managment, engeneering
# Quelles sont vos aspirations futures ?                                                                                                     -Becoming an industry expert\n-Becoming a part of managment \n
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                 Already started learning for this exam. This exam is a prove for profesionalism of PM as well as...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                   - interesting projects\n- world wide company \n- oportunity to develop
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                                                                                          - bureaucracy\n- overtime not paid
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                                   IF PM handling technical project they need to have technical background.
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                       98   \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                              Interface Management between the entities
# Quelles sont vos aspirations futures ?                                                                                      Progressively lead the Company, Buniness line within span of next 3-5 years\n
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                               Better Project Management organisation (Staffing)
# Si oui ou non, expliquez pourquoi ...                                                                 Yes surely.\nHowever time and the heavy workload has been the constraint for taking out time for...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     Lack of Consistancy in terms of support (Support offered based on results -Corrective and not pr...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                                                       Flexibility \nTrust \nOpportunity
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                                                                  Inconsistancy\nDecision making\nLoosing Technical expertise
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        Aggressive in the market and Pragmatism in execution (Right Prioritisation)...and focus on custo...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...  Change is Inevitable, but constantantly changing maybe harmful.  Good if it is predictable.\n\nT...
# Si autre, à préciser(combined)                                                                        Clear roles and responsibility in case of shared responsibilities.\nBetter support in terms of t...
#
#                                                                                                                                                                                                       99   \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                                                                          Team management, with technical aspects.
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                                      It's always interesting to have training / certification to improve our skills
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                      Freedom given to the project manager\nNew techical skills discoverd\nRelation ship with other JC...
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          Complexity of promocore\nDificulty to have a clear process for PM\nLack of support for secretari...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                                              Recognize at is just value the work and give future prospects
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                       100  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                                                                        To be better Communicator, adaptable ,agile
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                                                                                                  I am PMP Certified
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                      1. The way John Cockerill's presence in different continents supports in project execution.\n2. ...
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          1. Strong Functional matrix, in spite of being an OEM\n2. Lack of live platform for Project Moni...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                          1. Professional Ethics\n2. Proper and proactive planning\n3. Vision of objectives
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...           Thank you for giving this opportunity to express, hoping every comment brings some value.
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                       101  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                To lead  team on group  level for international  project  where multiple  entities will be invol...
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                  PMP certification  will help us to apply worlds best proven Project Management  practices which...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     Improper Work load management  of individual & not giving appropriate  guidance  & support from ...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                      1.Tools  like PROMOCORE, SAP & MSP help a lot in monitoring  & controlling  scope, schedule & co...
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          1. Technical information sharing within different  entities are improper \n2. Cost & margin shar...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                                                             good training  & global exposure  to the team
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...  1. Improvement in investment  for different  sectors  in India other  than steel.\n2. Wedges  fo...
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                       102
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                                                                                             Top management and CEO
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                                                                                              I am already certified
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     Senior managers who are suppose to make and give critical decision, seems to be on back-foot. Fi...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                                                           Good initiative in using O365.
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          Senior or Top management do not own the responsibility of negative outcome of their decisions an...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        Each functional team need to own the project, it's not just Project Manager.\nProject Manager sa...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
# [10 rows x 103 columns]

# %%
combined['corpus'] = combined[combined.columns[1:]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)
combined
# Out:
#                                                                                                                                                                                                         0  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                                                         Une croissance sur des projets techniques plus complexes.
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                 J’ai l’impression que l’entreprise accorde beaucoup d’importance aux certifications détenues par...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                      La culture du groupe \nLa structuration et l’harmonisation des processus \nLa disponibilité des ...
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          L’absence de vision à long terme \nLe manque de communication du management \nL’absence de leade...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        Donner davantage d’autonomie et de pouvoir au chef de projet sur son projet. \nIl n’est pas norm...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                         1  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                                                                           continuer à gérer des équipes de projets
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?              arrêter cette ambiguïté du tandem PM et TPM, il faut un seul patron dans une équipe et c'est le PM
# Si oui ou non, expliquez pourquoi ...                                                                                                                                                ce serait une redite
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                           diversité des business, excepté la défense.\nla localisation\n
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          entreprise qui donne une image moderne mais qui est ancrée dans son passé, gérée par des manager...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        remettre le PM au centre du projet, c'est le patron de l'équipe projet.\nmoderniser cet outil pr...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                         bonne chance
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                         2  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                j'ai répondu au questionnaire comme si j étais toujours PM dans un secteur, fonction que j ai qu...
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?             Difficulté d'avoir accès à des ressources de qualité (mobilisée sur un autre projet ou pas dispo...
# Si oui ou non, expliquez pourquoi ...                                                                                            Ancrage des formations suivies en interne\nValorisation de notre métier
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                      Variété des projets, niveau de responsabilité assez jeune, produits
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          combat permanent pour les ressources, portefeuille de produits assez large- pour un non technici...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                 réduire la charge horaire \ntrouver des moyens d'optimiser les taches très administratives
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                         3  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                     administratives : gestion des documents, title-block, flux d'approbation, préparation de work pa...
# Quelles sont vos aspirations futures ?                                                                          Avoir une équipe à gérer de chargés d'affaires. Le duo PM/TPM ne s'applique pas forcément
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                        reconnaissance salariale
# Si oui ou non, expliquez pourquoi ...                                                                                                                                                       déjà certifié
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                      environnement international\nnouveaux produits (hydrogène, tours solaire, etc)\ngroupe en expans...
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          la charge administrative et trop d'outils différents mis en place\nla perte de référents techniq...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        perspective d'avenir :  A-t-on vraiment envie d'être PM sur des HRSGs pendant 10 ans?\nRendre pl...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                               4  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                             -
# Quelles sont vos aspirations futures ?                                                                                                                   Rester Project manager
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                     -
# Si oui ou non, expliquez pourquoi ...                                                                                     Pas le temps personnel a accorder au vu de la famille
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                             -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                  Groupe à taille humaine\nAutonomie\nDiversité
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          Lourdeur administrative\nManque de support informatique\nTrop de réunions
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                                                     Reconnaissance hiéerarchique
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                          -
# Si autre, à préciser(combined)                                                                                                                                         --------
#
#                                                                                                                                                                                                         5  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                        Dessin technique
# Quelles sont vos aspirations futures ?                                                                                                                                                    Responsable R&D
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                            Travailler en équipe
# Si oui ou non, expliquez pourquoi ...                                                                 Pour être sur d'appliquer correctement une bonne gestion de projet à mes affaires pour qu'elles ...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                                          Dimension international, Formation, Opportunité
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                                                                                                                   Pas d'avis
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                                   L'aspect non répétitif, non monotone, découverte de plein de technologie
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                         6  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                          Knowledge Management\nCoaching
# Quelles sont vos aspirations futures ?                                                                                                       not relevant for this survey
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                                                                     Standardization
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                     Challenging, flexible and motivating
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          PM is not seen as a decision maker fully accountable for his choise
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                                               Create a more accountable PM
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                    -
# Si autre, à préciser(combined)                                                                                                                                   --------
#
#                                                                                                                                                                                                         7  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                Pouvoir gérer des projets plus gros/complexes où j'ai des personnes vraiment impliqués dessus (e...
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                 Oui car j'ai besoin d'outils pour être à même de gérer des projets de divers types, de plus en p...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     Mieux savoir faire les parts de choses et "remballer" les clients avec ses attentes peu cohérent...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                                        Polyvalence - Vue d'ensemble\nContacts\nConcret\n
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                                                                Administratif\nCollaborateurs non motivés\nTrajets en voiture
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        Remettre le chef de projet au centre du projet et alléger certaines procédures/formulaires inter...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                        - Plus challenger\n- Savoir monter au front lors de situations délicates avec clients/fournisseu...
#
#                                                                                                                                                                                                         8  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                Tout dépend de comment le métier de gestion de projet évoluéra au fil des années chez JCD. En pr...
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                 Je pense que la certification PMBOK nous donne beaucoup de possibilités. Les outils et méthodes ...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                                           Flexibilité, Autonomie et Support hiérarchique
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                                           Manque d'outil, processus pas adaptés (exercice budgétaire), quantité de reporting
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        Travailler en mode gestion de projet pour du vrai. Adapter / implémenter le mode multiprojet à l...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                         9  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                                                     Travailler sur des projets dans différentes parties du monde.
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                                            Cela facilite la mobilité car nous travaillons  avec les mêmes standards
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     Il y a un manque de soutien à la fonction de PM et cette fonction est systématiquement pointées ...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                          diversité des projets\nprojets internationaux\nniveaux des challenges proposés
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          Trop des niveaux de management et de fonctions transversales peu rentables \nBeaucoup trop de Fr...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        Clarifier les statuts des freelance ( durée ou objet de la mission ). Il y a trop de freelance q...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                       ...  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                     ...
# Quelles sont vos aspirations futures ?                                                                ...
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?             ...
# Si oui ou non, expliquez pourquoi ...                                                                 ...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     ...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                      ...
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          ...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        ...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...  ...
# Si autre, à préciser(combined)                                                                        ...
#
#                                                                                                                                                                                                        94  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                     Functional activities like Participation in Kaizen, Daily Management, Opportunities be explored ...
# Quelles sont vos aspirations futures ?                                                                - Lead Projects Team at JC (all sectors option open preferred within India)\n- Lead Portfolio of...
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?             - Project Management with exposure to techno commercial experience & Industry experience as END ...
# Si oui ou non, expliquez pourquoi ...                                                                 I have attended the PMP foundation course from PMI already however could not appear on the exam ...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     Stress levels go high as - \n- functional goals supersede Project goals, increases MUDA (Waste) ...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                       - JCIL Project management concepts are bit different than JC as group but interesting to work w...
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                           - Matrix organization as a concept still not being rooted into individuals but functional domin...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        - Grab more orders to sustain in the business \n- Motivate employees to be committed, take chall...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...  Good initiative from the head quarters for a noble cause. Project Managers are key personnel on ...
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                        95  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                     Babysitting.\nWe have a VERY WEAK mid level management team (department managers) in the energy ...
# Quelles sont vos aspirations futures ?                                                                I would like to stay in project management and improve my skills and grow our team to reach its ...
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?             Schedule. Currently there is no functional schedule for engineering and thus, no way to hold eng...
# Si oui ou non, expliquez pourquoi ...                                                                                                                                            Already a certified PMP.
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     Mid level management (department managers) are non-existent/unresponsive and it makes it difficu...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                                               The POTENTIAL to grow and be successful.\n
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                                               Mid level leadership.\nAccountability at ALL LEVELS.\nStaffing inefficiencies.
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        It is not the value of the profession, it is the environment we have created surrounding the pro...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                             Hope someone actually reads this and its worth anything.
# Si autre, à préciser(combined)                                                                        We have a general lack of Project Management experience. There is no mentorship program in place...
#
#                                                                                                                                                                                                        96  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                training
# Quelles sont vos aspirations futures ?                                                                I would like to stick with John Cockerill and work in project management a little longer but I w...
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?              better support from mid/executive management, quicker responses on items concerning urgent issues,
# Si oui ou non, expliquez pourquoi ...                                                                                                                                                       I have my PMP
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     I would say my stress level is a 3 just in comparison to where it has been over the past year bu...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                           - working with people around the globe\n- diverse technologies
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          - reporting and constant changing in reporting \n- inefficient tools & processes (sometimes a co...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                                                                    fix the processes, procedures and tools
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                        97  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                 purchasing, site managment, engeneering
# Quelles sont vos aspirations futures ?                                                                                                     -Becoming an industry expert\n-Becoming a part of managment \n
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                 Already started learning for this exam. This exam is a prove for profesionalism of PM as well as...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                   - interesting projects\n- world wide company \n- oportunity to develop
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                                                                                          - bureaucracy\n- overtime not paid
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                                   IF PM handling technical project they need to have technical background.
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                        98  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                              Interface Management between the entities
# Quelles sont vos aspirations futures ?                                                                                      Progressively lead the Company, Buniness line within span of next 3-5 years\n
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                               Better Project Management organisation (Staffing)
# Si oui ou non, expliquez pourquoi ...                                                                 Yes surely.\nHowever time and the heavy workload has been the constraint for taking out time for...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     Lack of Consistancy in terms of support (Support offered based on results -Corrective and not pr...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                                                       Flexibility \nTrust \nOpportunity
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                                                                  Inconsistancy\nDecision making\nLoosing Technical expertise
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        Aggressive in the market and Pragmatism in execution (Right Prioritisation)...and focus on custo...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...  Change is Inevitable, but constantantly changing maybe harmful.  Good if it is predictable.\n\nT...
# Si autre, à préciser(combined)                                                                        Clear roles and responsibility in case of shared responsibilities.\nBetter support in terms of t...
#
#                                                                                                                                                                                                        99  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                                                                          Team management, with technical aspects.
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                                      It's always interesting to have training / certification to improve our skills
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                      Freedom given to the project manager\nNew techical skills discoverd\nRelation ship with other JC...
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          Complexity of promocore\nDificulty to have a clear process for PM\nLack of support for secretari...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                                              Recognize at is just value the work and give future prospects
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                       100  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                                                                        To be better Communicator, adaptable ,agile
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                                                                                                  I am PMP Certified
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                                                                                                                       -
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                      1. The way John Cockerill's presence in different continents supports in project execution.\n2. ...
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          1. Strong Functional matrix, in spite of being an OEM\n2. Lack of live platform for Project Moni...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                          1. Professional Ethics\n2. Proper and proactive planning\n3. Vision of objectives
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...           Thank you for giving this opportunity to express, hoping every comment brings some value.
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                       101  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                To lead  team on group  level for international  project  where multiple  entities will be invol...
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                  PMP certification  will help us to apply worlds best proven Project Management  practices which...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     Improper Work load management  of individual & not giving appropriate  guidance  & support from ...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                      1.Tools  like PROMOCORE, SAP & MSP help a lot in monitoring  & controlling  scope, schedule & co...
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          1. Technical information sharing within different  entities are improper \n2. Cost & margin shar...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                                                                             good training  & global exposure  to the team
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...  1. Improvement in investment  for different  sectors  in India other  than steel.\n2. Wedges  fo...
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                       102  \
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                                                                                                                       -
# Quelles sont vos aspirations futures ?                                                                                                                                             Top management and CEO
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?                                                                                                               -
# Si oui ou non, expliquez pourquoi ...                                                                                                                                              I am already certified
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     Senior managers who are suppose to make and give critical decision, seems to be on back-foot. Fi...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                                                                                           Good initiative in using O365.
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          Senior or Top management do not own the responsibility of negative outcome of their decisions an...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        Each functional team need to own the project, it's not just Project Manager.\nProject Manager sa...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...                                                                                                    -
# Si autre, à préciser(combined)                                                                                                                                                                   --------
#
#                                                                                                                                                                                                    corpus
# Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous                                     -,-,administratives : gestion des documents, title-block, flux d'approbation, préparation de wor...
# Quelles sont vos aspirations futures ?                                                                continuer à gérer des équipes de projets,j'ai répondu au questionnaire comme si j étais toujours...
# Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?             arrêter cette ambiguïté du tandem PM et TPM, il faut un seul patron dans une équipe et c'est le ...
# Si oui ou non, expliquez pourquoi ...                                                                 ce serait une redite,Ancrage des formations suivies en interne\nValorisation de notre métier ,dé...
# Commentaire libre pour vous exprimer sur votre niveau de stress :                                     -,-,-,-,-,-,Mieux savoir faire les parts de choses et "remballer" les clients avec ses attentes ...
# Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?                      diversité des business, excepté la défense.\nla localisation\n,Variété des projets, niveau de re...
# Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?                          entreprise qui donne une image moderne mais qui est ancrée dans son passé, gérée par des manager...
# Selon vous, quelle est la première action à prendre pour valoriser le métier ?                        remettre le PM au centre du projet, c'est le patron de l'équipe projet.\nmoderniser cet outil pr...
# Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir pr...  bonne chance,-,-,-,-,-,-,-,-,-,-,Je pense qu'il est important que JC se positionne sur le rôle d...
# Si autre, à préciser(combined)                                                                        --------,--------,--------,--------,--------,--------,- Plus challenger\n- Savoir monter au fron...
#
# [10 rows x 104 columns]

# %%
corpus = combined['corpus'].to_frame().reset_index()

# %%
# text cleaning and preparation
corpus['corpus'] = corpus['corpus'].str.replace('-', ' ')
corpus['corpus'] = corpus['corpus'].str.replace('\n', ' ')
corpus['corpus'] = corpus['corpus'].str.replace(',', ' ')
corpus['corpus'] = corpus['corpus'].str.strip()
corpus
# Out:
#                                                                                                  index  \
# 0                                    Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous
# 1                                                               Quelles sont vos aspirations futures ?
# 2            Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?
# 3                                                                Si oui ou non, expliquez pourquoi ...
# 4                                    Commentaire libre pour vous exprimer sur votre niveau de stress :
# 5                     Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?
# 6                         Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?
# 7                       Selon vous, quelle est la première action à prendre pour valoriser le métier ?
# 8  Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir p...
# 9                                                                       Si autre, à préciser(combined)
#
#                                                                                                 corpus
# 0  administratives : gestion des documents  title block  flux d'approbation  préparation de work pa...
# 1  continuer à gérer des équipes de projets j'ai répondu au questionnaire comme si j étais toujours...
# 2  arrêter cette ambiguïté du tandem PM et TPM  il faut un seul patron dans une équipe et c'est le ...
# 3  ce serait une redite Ancrage des formations suivies en interne Valorisation de notre métier  déj...
# 4  Mieux savoir faire les parts de choses et "remballer" les clients avec ses attentes peu cohérent...
# 5  diversité des business  excepté la défense. la localisation  Variété des projets  niveau de resp...
# 6  entreprise qui donne une image moderne mais qui est ancrée dans son passé  gérée par des manager...
# 7  remettre le PM au centre du projet  c'est le patron de l'équipe projet. moderniser cet outil pro...
# 8  bonne chance                     Je pense qu'il est important que JC se positionne sur le rôle d...
# 9  Plus challenger   Savoir monter au front lors de situations délicates avec clients/fournisseurs/...

# %%
master_corpus = corpus

# %%
corpus['token'] = corpus['corpus'].map(lambda x: word_tokenize(x.lower()))

# %%
sw_en = stopwords.words('english')
sw_fr = stopwords.words('french')
stops = sw_en + sw_fr

other_sw = ['.', ',', '/', '-', ':']
stops.extend(other_sw)

# %%
corpus['corpus']
# Out:
# 0    administratives : gestion des documents  title...
# 1    continuer à gérer des équipes de projets j'ai ...
# 2    arrêter cette ambiguïté du tandem PM et TPM  i...
# 3    ce serait une redite Ancrage des formations su...
# 4    Mieux savoir faire les parts de choses et "rem...
# 5    diversité des business  excepté la défense. la...
# 6    entreprise qui donne une image moderne mais qu...
# 7    remettre le PM au centre du projet  c'est le p...
# 8    bonne chance                     Je pense qu'i...
# 9    Plus challenger   Savoir monter au front lors ...
# Name: corpus, dtype: object

# %%
for i in range(len(corpus['token'])):
    corpus.at[i,'token'] = [word for word in corpus['token'][i] if word not in stops]

# %%
corpus
# Out:
#                                                index  \
# 0  Si vous effectuez d'autres tâches, veuillez l'...
# 1             Quelles sont vos aspirations futures ?
# 2  Y a-t-il un facteur supplémentaire qui vous se...
# 3              Si oui ou non, expliquez pourquoi ...
# 4  Commentaire libre pour vous exprimer sur votre...
# 5  Selon vous, quels sont les 3 aspects les plus ...
# 6  Selon vous, quels sont les 3 aspects les plus ...
# 7  Selon vous, quelle est la première action à pr...
# 8  Si vous le souhaitez, n'hésitez pas à ajouter ...
# 9                     Si autre, à préciser(combined)
#
#                                               corpus  \
# 0  administratives : gestion des documents  title...
# 1  continuer à gérer des équipes de projets j'ai ...
# 2  arrêter cette ambiguïté du tandem PM et TPM  i...
# 3  ce serait une redite Ancrage des formations su...
# 4  Mieux savoir faire les parts de choses et "rem...
# 5  diversité des business  excepté la défense. la...
# 6  entreprise qui donne une image moderne mais qu...
# 7  remettre le PM au centre du projet  c'est le p...
# 8  bonne chance                     Je pense qu'i...
# 9  Plus challenger   Savoir monter au front lors ...
#
#                                                token
# 0  [administratives, gestion, documents, title, b...
# 1  [continuer, gérer, équipes, projets, j'ai, rép...
# 2  [arrêter, cette, ambiguïté, tandem, pm, tpm, f...
# 3  [redite, ancrage, formations, suivies, interne...
# 4  [mieux, savoir, faire, parts, choses, ``, remb...
# 5  [diversité, business, excepté, défense, locali...
# 6  [entreprise, donne, image, moderne, ancrée, pa...
# 7  [remettre, pm, centre, projet, c'est, patron, ...
# 8  [bonne, chance, pense, qu'il, important, jc, p...
# 9  [plus, challenger, savoir, monter, front, lors...

# %% [markdown]
# ### LDA

# %%
corpus
# Out:
#                                                index  \
# 0  Si vous effectuez d'autres tâches, veuillez l'...
# 1             Quelles sont vos aspirations futures ?
# 2  Y a-t-il un facteur supplémentaire qui vous se...
# 3              Si oui ou non, expliquez pourquoi ...
# 4  Commentaire libre pour vous exprimer sur votre...
# 5  Selon vous, quels sont les 3 aspects les plus ...
# 6  Selon vous, quels sont les 3 aspects les plus ...
# 7  Selon vous, quelle est la première action à pr...
# 8  Si vous le souhaitez, n'hésitez pas à ajouter ...
# 9                     Si autre, à préciser(combined)
#
#                                               corpus  \
# 0  administratives : gestion des documents  title...
# 1  continuer à gérer des équipes de projets j'ai ...
# 2  arrêter cette ambiguïté du tandem PM et TPM  i...
# 3  ce serait une redite Ancrage des formations su...
# 4  Mieux savoir faire les parts de choses et "rem...
# 5  diversité des business  excepté la défense. la...
# 6  entreprise qui donne une image moderne mais qu...
# 7  remettre le PM au centre du projet  c'est le p...
# 8  bonne chance                     Je pense qu'i...
# 9  Plus challenger   Savoir monter au front lors ...
#
#                                                token
# 0  [administratives, gestion, documents, title, b...
# 1  [continuer, gérer, équipes, projets, j'ai, rép...
# 2  [arrêter, cette, ambiguïté, tandem, pm, tpm, f...
# 3  [redite, ancrage, formations, suivies, interne...
# 4  [mieux, savoir, faire, parts, choses, ``, remb...
# 5  [diversité, business, excepté, défense, locali...
# 6  [entreprise, donne, image, moderne, ancrée, pa...
# 7  [remettre, pm, centre, projet, c'est, patron, ...
# 8  [bonne, chance, pense, qu'il, important, jc, p...
# 9  [plus, challenger, savoir, monter, front, lors...

# %%
data = corpus['token']
data_words = list(corpus['token'])
print(data_words[:1])
# Out:
# [['administratives', 'gestion', 'documents', 'title', 'block', 'flux', "d'approbation", 'préparation', 'work', 'package', 'toutes', 'tâches', 'peu', 'valeurs', 'ajoutées', 'time', 'consuming', 'dessin', 'technique', 'knowledge', 'management', 'coaching', 'problem', 'solving', 'peu', 'méthodes', 'équipes', 'surchargées', 'perte', 'connaissances', 'techniques', "d'où", 'problèmes', 'retards', 'conduite', 'chantier', 'support', 'autres', 'départements', 'méthodologie', 'mettre', 'place', '+', 'suivi', 'planning', "d'autres", 'projets', 'lien', 'entre', 'fournisseurs', 'départements', 'alignement', 'technique', 'commercial', 'fournisseurs', 'réalisation', "d'une", 'partie', 'technique', 'projet', 'sourcing', 'reporting', 'management', '...', 'gestion/suivi', 'fdr', 'chantier', "jusqu'au", 'closing', 'financier', 'client', 'sst', 'rédaction', 'négociation', 'contract', 'change', 'order', 'contract', 'management', 'résolution', 'conflit', 'interne', 'analyse', 'écarts', 'suivi', 'fabrications', 'sous', 'traitant', 'suivi/coordination', 'points', 'suivants', 'suivi', 'lettre', 'credit', 'amendements', 'suivi', 'garanties', 'bancaires', 'amendements', '(', 'suivi', 'réduction', 'garantie', 'prorata', 'livraisons', ')', 'responsable', 'hse', 'formations', 'participation', 'projets', 'développement', 'secteur/groupe', 'plm', 'digibuy', 'etc', 'suivi', 'contractuel/claim', 'coordination', 'contracts', 'managers', 'suivi', 'coordination', 'secrétariat', 'technique', 'gestion', 'documentaire', '+', 'pointage', 'recherche', 'partenaires', 'négociation', 'achats', 'maitrise', 'contractuelle', 'chiffrage', 'gros', 'poste', 'temps', 'également', 'études', 'techniques', 'remarque', 'très', 'difficile', 'classer', 'fonction', 'temps', 'consacré', 'tout', 'dépend', 'stade', 'taille', 'structure', 'projet', 'tout', 'cas', 'répartition', 'temps', 'thèmes', 'proposés', "n'est", 'simple', 'double', 'cela', 'joue', 'qq', '%', 'près', '...', 'cette', 'question', 'manque', 'pertinence', 'sens', 'peux', 'ajouter', 'tâches', 'suivantes', 'communication', 'hiérarchie', 'communication', 'shared', 'services', 'internes', '(', 'compta', 'ict', 'rh', '...', ')', 'logistique', 'suivi', 'fournisseurs', 'sous', 'tous', 'aspects', 'plan', "d'expédition", 'projet', 'montage', 'site', '10.', 'développement', 'procédures', 'achat', "d'équipements", 'spécifiques', 'complexes', 'suivi', 'fournisseur', 'qualité', 'fabrication', 'suivi', 'chantier', 'mise', 'service', 'chiffrage', 'formation', '(', 'membres', "l'équipe", 'retour', "d'expérience", 'etc', ')', 'vérification', '(', 'travail', 'fait', 'interne', 'documents', 'soumis', 'interne/externe', ')', 'acheteur', 'qualité', 'suivi', 'réception', 'équipement', 'site', 'suivi', 'montage', 'suivi', 'activités', 'qa', 'suivi', 'logistique', '(', 'transport/douanes', ')', 'préparation', 'documents', "j'ai", 'bcp', 'formations', 'car', "j'ai", 'commencé', 'chez', 'jc', '5', 'semaines', 'lecture', 'cahiers', 'charges', 'suivi', 'chantier', 'commissioning', 'mise', 'service', 'visite', 'site', 'élaboration', 'réflexion', 'moyens', 'sécurité', 'mettre', 'place', 'budgétisation', 'suppléments', 'trouble', 'shooting', 'gestion', 'imprévus', 'conduite', 'chantier', 'prépa', 'chantier', 'amélioration', 'continue', 'certain', 'process', 'check', 'liste', 'réunion', 'client', 'sécurité', 'conduite', 'chantier', 'planification', "l'ensemble", 'marché', 'project', 'engineer', 'bu', 'locos', 'pm', 'pe', 'souvent', 'faits', 'personne', 'remarque', 'question', '8', 'difficile', 'répondre', "l'activité", 'pm', 'epc', 'démarre', ';', "c'est", 'juste', '``', 'best', 'guess', "''", 'non', 'réalisation', 'contrôle', 'spécifications', 'techniques', "l'approvisionnement", 'pièces', 'commerces', 'éléments', 'fabrication', 'ainsi', 'montage', 'installations', 'chez', 'clients', 'trying', 'upsell', 'change', 'orders', 'manage', 'scope', 'mainly', 'increase', 'contract', 'margin', 'values', 'kaizens', 'continuous', 'improvements', 'also', 'responsi ...

# %%
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

def process_words(texts, stop_words=stops, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """Remove Stopwords, Form Bigrams, Trigrams and Lemmatization"""
    texts = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]
    texts = [bigram_mod[doc] for doc in texts]
    texts = [trigram_mod[bigram_mod[doc]] for doc in texts]
    texts_out = []
    nlp = spacy.load('fr_core_news_sm', disable=['parser', 'ner'])
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    # remove stopwords once more after lemmatization
    
    texts_out = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts_out]    
    return texts_out

data_ready = process_words(data_words)  # processed Text Data!

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_ready)

# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in data_ready]

# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=4, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=10,
                                           passes=10,
                                           alpha='symmetric',
                                           iterations=100,
                                           per_word_topics=True)

print(lda_model.print_topics())
# Out:
# [(0, '0.027*"projet" + 0.010*"project" + 0.009*"gestion" + 0.009*"manqu" + 0.008*"fonction" + 0.008*"diversité" + 0.007*"travail" + 0.007*"plus" + 0.006*"outil" + 0.006*"technique"'), (1, '0.018*"projet" + 0.012*"plus" + 0.010*"stres" + 0.009*"project" + 0.007*"client" + 0.007*"manager" + 0.007*"autre" + 0.006*"fonction" + 0.006*"support" + 0.006*"travail"'), (2, '0.023*"projet" + 0.016*"gestion" + 0.012*"plus" + 0.012*"suivre" + 0.010*"certification" + 0.009*"management" + 0.009*"formation" + 0.008*"pouvoir" + 0.007*"permettre" + 0.007*"project"'), (3, '0.019*"projet" + 0.012*"plus" + 0.010*"project" + 0.010*"gestion" + 0.010*"management" + 0.008*"fonction" + 0.006*"gérer" + 0.005*"lead" + 0.004*"responsable" + 0.004*"manager"')]

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']
    
    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data_ready)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             2.0              0.9978
# 1            1             3.0              0.8561
# 2            2             0.0              0.9986
# 3            3             2.0              0.9993
# 4            4             1.0              0.9990
# 5            5             0.0              0.9991
# 6            6             0.0              0.9994
# 7            7             0.0              0.9992
# 8            8             1.0              0.9987
# 9            9             1.0              0.9991
#
#                                             Keywords  \
# 0  projet, gestion, plus, suivre, certification, ...
# 1  projet, plus, project, gestion, management, fo...
# 2  projet, project, gestion, manqu, fonction, div...
# 3  projet, gestion, plus, suivre, certification, ...
# 4  projet, plus, stres, project, client, manager,...
# 5  projet, project, gestion, manqu, fonction, div...
# 6  projet, project, gestion, manqu, fonction, div...
# 7  projet, project, gestion, manqu, fonction, div...
# 8  projet, plus, stres, project, client, manager,...
# 9  projet, plus, stres, project, client, manager,...
#
#                                                 Text
# 0  [administratif, gestion, document, titl, flux,...
# 1  [continuer, gérer, projet, questionnaire, touj...
# 2  [arrêter, ambiguïté, pm, tpm, faut, seul, patr...
# 3  [redite, ancrage, formation, suivre, interne, ...
# 4  [mieux, savoir, faire, part, chose, remballer,...
# 5  [diversité, busines, défense, localisation, pr...
# 6  [entreprise, donn, image, moderne, ancrée, pas...
# 7  [remettre, centre, projet, patron, projet, mod...
# 8  [bon, chance, pense, important, positionne, rô...
# 9  [plus, challenger, savoir, monter, front, lors...

# %%
# df_dominant_topic.to_excel('Dominant_Topic.xlsx')

# %%
# Display setting to show more characters in column
pd.options.display.max_colwidth = 100

sent_topics_sorteddf_mallet = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf_mallet.head(10)
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0        0.0              0.9994
# 1        1.0              0.9991
# 2        2.0              0.9993
# 3        3.0              0.8561
#
#                                                                                            Keywords  \
# 0             projet, project, gestion, manqu, fonction, diversité, travail, plus, outil, technique
# 1                  projet, plus, stres, project, client, manager, autre, fonction, support, travail
# 2  projet, gestion, plus, suivre, certification, management, formation, pouvoir, permettre, project
# 3           projet, plus, project, gestion, management, fonction, gérer, lead, responsable, manager
#
#                                                                                    Representative Text
# 0  [entreprise, donn, image, moderne, ancrée, passer, géré, manager, issu, mond, production, gestio...
# 1  [plus, challenger, savoir, monter, front, lors, situation, délicat, client, fournisseur, autre, ...
# 2  [redite, ancrage, formation, suivre, interne, valorisation, métier, déjà, certifier, temps, pers...
# 3  [continuer, gérer, projet, questionnaire, toujours, secteur, fonction, plus, interesser, enquete...

# %%
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=stops,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')
    
plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
from collections import Counter
topics = lda_model.show_topics(formatted=False)
data_flat = [w for w_list in data_ready for w in w_list]
counter = Counter(data_flat)

out = []
for i, topic in topics:
    for word, weight in topic:
        out.append([word, i , weight, counter[word]])

df = pd.DataFrame(out, columns=['word', 'topic_id', 'importance', 'word_count'])        

# Plot Word Count and Weights of Topic Keywords
fig, axes = plt.subplots(2, 2, figsize=(16,10), sharey=True, dpi=160)
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]
for i, ax in enumerate(axes.flatten()):
    ax.bar(x='word', height="word_count", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.5, alpha=0.3, label='Word Count')
    ax_twin = ax.twinx()
    ax_twin.bar(x='word', height="importance", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.2, label='Weights')
    ax.set_ylabel('Word Count', color=cols[i])
    ax_twin.set_ylim(0, 0.030); ax.set_ylim(0, 3500)
    ax.set_title('Topic: ' + str(i), color=cols[i], fontsize=16)
    ax.tick_params(axis='y', left=False)
    ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
    ax.legend(loc='upper left'); ax_twin.legend(loc='upper right')

fig.tight_layout(w_pad=2)    
fig.suptitle('Word Count and Importance of Topic Keywords', fontsize=22, y=1.05)    
plt.show()
# Out:
# <ipython-input-26-3105a4a9aef8>:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
# <ipython-input-26-3105a4a9aef8>:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
# <ipython-input-26-3105a4a9aef8>:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
# <ipython-input-26-3105a4a9aef8>:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')

# %%
# Sentence Coloring of N Sentences
def topics_per_document(model, corpus, start=0, end=1):
    corpus_sel = corpus[start:end]
    dominant_topics = []
    topic_percentages = []
    for i, corp in enumerate(corpus_sel):
        topic_percs, wordid_topics, wordid_phivalues = model[corp]
        dominant_topic = sorted(topic_percs, key = lambda x: x[1], reverse=True)[0][0]
        dominant_topics.append((i, dominant_topic))
        topic_percentages.append(topic_percs)
    return(dominant_topics, topic_percentages)

dominant_topics, topic_percentages = topics_per_document(model=lda_model, corpus=corpus, end=-1)            

# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])
dominant_topic_in_each_doc = df.groupby('Dominant_Topic').size()
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()

# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in lda_model.show_topics(formatted=False) 
                                 for j, (topic, wt) in enumerate(topics) if j < 3]

df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(', \n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %%
from matplotlib.ticker import FuncFormatter

# Plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4), dpi=120, sharey=True)

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x, pos: 'Topic ' + str(x)+ '\n' + df_top3words.loc[df_top3words.topic_id==x, 'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Number of Documents by Dominant Topic', fontdict=dict(size=10))
ax1.set_ylabel('Number of Documents')
ax1.set_ylim(0, 1000)

# Topic Distribution by Topic Weights
ax2.bar(x='index', height='count', data=df_topic_weightage_by_doc, width=.5, color='steelblue')
ax2.set_xticks(range(df_topic_weightage_by_doc.index.unique().__len__()))
ax2.xaxis.set_major_formatter(tick_formatter)
ax2.set_title('Number of Documents by Topic Weightage', fontdict=dict(size=10))
# Out:
# Text(0.5, 1.0, 'Number of Documents by Topic Weightage')

# %% [markdown]
# ### KeyBERT

# %%
from keybert import KeyBERT

# %%
master_corpus
# Out:
#                                                                                                  index  \
# 0                                    Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous
# 1                                                               Quelles sont vos aspirations futures ?
# 2            Y a-t-il un facteur supplémentaire qui vous semble utile de mentionner ? Si oui, lequel ?
# 3                                                                Si oui ou non, expliquez pourquoi ...
# 4                                    Commentaire libre pour vous exprimer sur votre niveau de stress :
# 5                     Selon vous, quels sont les 3 aspects les plus intéressants chez John Cockerill ?
# 6                         Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?
# 7                       Selon vous, quelle est la première action à prendre pour valoriser le métier ?
# 8  Si vous le souhaitez, n'hésitez pas à ajouter un commentaire. \n\nNous vous remercions d'avoir p...
# 9                                                                       Si autre, à préciser(combined)
#
#                                                                                                 corpus
# 0  administratives : gestion des documents  title block  flux d'approbation  préparation de work pa...
# 1  continuer à gérer des équipes de projets j'ai répondu au questionnaire comme si j étais toujours...
# 2  arrêter cette ambiguïté du tandem PM et TPM  il faut un seul patron dans une équipe et c'est le ...
# 3  ce serait une redite Ancrage des formations suivies en interne Valorisation de notre métier  déj...
# 4  Mieux savoir faire les parts de choses et "remballer" les clients avec ses attentes peu cohérent...
# 5  diversité des business  excepté la défense. la localisation  Variété des projets  niveau de resp...
# 6  entreprise qui donne une image moderne mais qui est ancrée dans son passé  gérée par des manager...
# 7  remettre le PM au centre du projet  c'est le patron de l'équipe projet. moderniser cet outil pro...
# 8  bonne chance                     Je pense qu'il est important que JC se positionne sur le rôle d...
# 9  Plus challenger   Savoir monter au front lors de situations délicates avec clients/fournisseurs/...

# %%
kw_model = KeyBERT()
master_corpus['keywords'] = master_corpus['corpus'].map(lambda x: kw_model.extract_keywords(x) )

# %%
master_corpus['keywords'][0][0]
# Out:
# ('départements', 0.3761)

# %%
# master_corpus.to_excel("keyBERT_results.xlsx")
