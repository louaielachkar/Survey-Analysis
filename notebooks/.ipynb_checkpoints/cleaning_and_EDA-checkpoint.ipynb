# %%
import pandas as pd
from spacy_langdetect import LanguageDetector
import spacy

# %%
df = pd.read_excel("DATA Enquete.xlsx")

# %%
df
# Out:
#       ID Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous  \
# 0      1                                                NaN
# 1      2                                                NaN
# 2      3                                                NaN
# 3      4  administratives : gestion des documents, title...
# 4      5                                                NaN
# ..   ...                                                ...
# 98    99         Interface Management between the entities
# 99   100                                                NaN
# 100  101                                                NaN
# 101  102                                                NaN
# 102  103                                                NaN
#
#                 Quelles sont vos aspirations futures ?  \
# 0    Une croissance sur des projets techniques plus...
# 1             continuer à gérer des équipes de projets
# 2    j'ai répondu au questionnaire comme si j étais...
# ...

# %%
df.set_index('ID')
# Out:
#     Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous  \
# ID
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    administratives : gestion des documents, title...
# 5                                                  NaN
# ..                                                 ...
# 99          Interface Management between the entities
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
#
#                 Quelles sont vos aspirations futures ?  \
# ID
# 1    Une croissance sur des projets techniques plus...
# 2             continuer à gérer des équipes de projets
# 3    j'ai répondu au questionnaire comme si j étais...
# ...

# %%
percent_missing = (df.isnull().sum() * 100 / len(df)).sort_values().round(2).astype(str) + "%"
missing_value_df = pd.DataFrame({'percent_missing': percent_missing})
missing_value_df
# Out:
#                                                    percent_missing
# ID                                                            0.0%
# Quelles sont vos aspirations futures ?                        0.0%
# Selon vous, quels sont les 3 aspects les plus p...            0.0%
# Selon vous, quels sont les 3 aspects les plus i...            0.0%
# Selon vous, quelle est la première action à pre...            0.0%
# Si oui ou non, expliquez pourquoi ...                        0.97%
# Y a-t-il un facteur supplémentaire qui vous sem...          50.49%
# A quel niveau le placeriez-vous dans le ranking...          51.46%
# Commentaire libre pour vous exprimer sur votre ...          54.37%
# Si vous effectuez d'autres tâches, veuillez l'i...          56.31%
# Si vous le souhaitez, n'hésitez pas à ajouter u...          75.73%
# Si autre, à préciser ... :                                  77.67%
# Si autre, à préciser ... :3                                 85.44%
# ...

# %%
df["Quelles sont vos aspirations futures ?"]
# Out:
# pandas.core.series.Series

# %%
nlp = spacy.load('en_core_web_sm') 
nlp.add_pipe(LanguageDetector(), name='language_detector', last=True)

# %%
def detect_language(text):
    doc = nlp(text)
    lang = doc._.language
    return lang['language']

# %%
detect_language("Hi there! How are you doing?")
# Out:
# 'en'

# %%
df['lang1'] = df["Quelles sont vos aspirations futures ?"].apply(detect_language)
df['lang2'] = df["Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?"].apply(detect_language)

# %%
temp = pd.concat([series1, series2], axis=1)
temp = temp.rename(columns={
    "Quelles sont vos aspirations futures ?": "lang1",
    "Selon vous, quels sont les 3 aspects les plus pénibles chez John Cockerill ?": "lang2"
})

# %%
df.loc[~(df['lang1'] == df['lang2'])]
# Out:
#       ID Si vous effectuez d'autres tâches, veuillez l'indiquer ci-dessous  \
# 4      5                                                NaN
# 5      6                                   Dessin technique
# 13    14  Lien entre les fournisseurs et nos département...
# 24    25                                    Responsable HSE
# 26    27                                                NaN
# 28    29                                                NaN
# 33    34                                                NaN
# 40    41                                                NaN
# 54    55                                                NaN
# 57    58                                                NaN
# 58    59                                                NaN
# 60    61  Suivi des réception des équipement sur Site, S...
# 78    79                                                NaN
# 79    80                                                NaN
# ...

# %%
df.to_excel("enquete_clean.xlsx")
